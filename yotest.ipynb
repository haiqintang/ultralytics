# %%
from ultralytics import YOLO

# Create a new YOLO11n-OBB model from scratch
model = YOLO("yolo12n-obb.yaml")
# Out:
# Channels: 4

# %%
# Train the model on the custom dataset
results = model.train(data="/home/haiqin/samba/private/dataset/yolo_obb/misplace.yaml", epochs=5, imgsz=128)
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227 🚀 Python-3.13.5 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 7706MiB)
# ...

# %%
model = YOLO("/home/haiqin/work/adc/trunk/sadc-ai/ultralytics/runs/obb/train2/weights/best.pt")

# %%
results = model.val(data="/home/haiqin/samba/private/dataset/yolo_obb/misplace.yaml")
# Out:
# Ultralytics 8.3.227 🚀 Python-3.13.5 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 7706MiB)
# YOLO12n-obb summary (fused): 168 layers, 2,628,638 parameters, 0 gradients, 6.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 12.6±1.9 MB/s, size: 61.9 KB)
# val: Scanning /home/haiqin/samba/private/dataset/yolo_obb/labels/val.cache... 7570 images, 3768 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7570/7570 13.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 474/474 15.5it/s 30.6s<0.0s
#                    all       7570       3802      0.873      0.901      0.931      0.732
# Speed: 0.0ms preprocess, 0.4ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/haiqin/work/adc/trunk/sadc-ai/ultralytics/runs/obb/val
